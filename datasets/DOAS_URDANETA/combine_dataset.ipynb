# %%
from pathlib import Path
import pandas as pd

# 1. Define folder path and output file
folder_path = Path("./DOAS_URDANETA")
output_file = folder_path / "combined_output.csv"

# 2. Find all CSV files in the folder
csv_files = list(folder_path.glob("*.csv"))

# Optional: exclude the output file if it already exists
csv_files = [f for f in csv_files if f.name != output_file.name]

if not csv_files:
    raise FileNotFoundError("No CSV files found in the specified directory.")

# 3. Read each CSV into a list of DataFrames
# Tip: Use `f.stem` to track the source filename in a column
df_list = [pd.read_csv(file).assign(source_file=file.name) for file in csv_files]

# 4. Concatenate all DataFrames into one
combined_df = pd.concat(df_list, ignore_index=True)

# 5. Save the combined data
combined_df.to_csv(output_file, index=False)

print(f"Successfully combined {len(csv_files)} files into {output_file}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 21
#      18 df_list = [pd.read_csv(file).assign(source_file=file.name) for file in csv_files]
#      20 # 4. Concatenate all DataFrames into one
# ---> 21 combined_df = pd.concat(df_list, ignore_index=True)
#      23 # 5. Save the combined data
#      24 combined_df.to_csv(output_file, index=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
# ...
