# %%
from pathlib import Path
import pandas as pd

# %%
folder_path=Path('../datasets/DOAS_URDANETA')y

csv_file=folder_path.glob('*.csv')
df_list=[pd.read_csv(file) for file in csv_file]

# %%
if df_list:
    combined_df = pd.concat(df_list, ignore_index=True)
    print(f"Successfully combined {len(df_list)} CSV files!")
else:
    print("No CSV files found in the directory.")
# Out:
# No CSV files found in the directory.
